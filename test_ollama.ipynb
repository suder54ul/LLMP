# %% [markdown]
# <a href="https://colab.research.google.com/github/suder54ul/LLMP/blob/main/test_ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage

# %%
# Connect to your local Ollama model
llm = ChatOllama(
    model="llama3.1:8b",  # this is the instruct model, for base model, append -text
    temperature=0.7,      # creativity level
    num_predict=512       # max tokens to generate
)

# %%
# Simple test
response = llm.invoke([HumanMessage(content=" Explain what Large Language Model is in 3 sentences.")])
print(response.content)
